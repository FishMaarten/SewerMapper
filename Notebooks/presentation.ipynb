# %% [raw]
# import bpy
# import json
# obj = C.selected_objects[0]
# verts = obj.data.vertices
# verts = list(map(lambda v: v.co, verts))
# verts = list(map(lambda v: list(i for i in v), verts))
# with open("/home/becode/Projects/SewerMapper/json/shaft2.json", "w") as file:
#     json.dump(verts, file)

# %%
from cloudtool import CloudSchematic

# %%
import json
with open("/home/becode/Projects/SewerMapper/cylinder_SEG.json", "r") as file:
    cs = CloudSchematic(json.load(file))

# %%
cs.generate(True)

# %%
cs.cross_section()

# %%
cs.project()

# %%
cs.shaft_circles()
cs.project_shaft()
# Out:
# (<Figure size 432x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa328347150>)

# %% [markdown]
# Components:
# -----------
#
# 1. Shaft
# 2. Chamber
# 3. Horizontal flow
#
#
# Visualization:
# --------------
#
# 1. PlyData module
# 2. Blender
# 3. PyVista
# 4. Json + Matplotlib
# 5. Santosh...
#
# Clustering:
# -----------
#
# Spectral clustering for man-hole components
#
#
# Chamber:
# --------
#
# 1. Cluster cuboid faces
# 2. RANSAC-algo
#
# 3. Circle Fitting
#
# Shaft:
# ------
#
# (Collection of cylinders)
#
# Z-bound cuts, best fit, bad center, radius, fit center (single cylinder)
#
#
# groupby(.1), cross_section, cluster on radius, regression on clusters
# (note: share_x axis, show-steps)
#
# CloudSchematic:
# ---------------
#
# !Dumbed down code approach(optional)!
#
# Demonstration... practiced and selected for success
